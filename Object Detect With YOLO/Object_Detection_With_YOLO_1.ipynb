# %%
# Import Library For Generate Dataset
from IPython.display import Image, clear_output
# !pip install roboflow
# !pip install ultralytics
clear_output()

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="m0ufdgTH3QE1FmaTjxYA")
project = rf.workspace("politeknik-harapan-bersama-o0fas").project("detection-fresh-fish")
version = project.version(4)
dataset = version.download("yolov8-obb")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Detection-Fresh-Fish-4 in yolov8-obb:: 100%|██████████| 3910/3910 [00:00<00:00, 5502.69it/s]

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.35 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.5/78.2 GB disk)

# %%
# !yolo detect train data=/content/Detection-Fresh-Fish-4/data.yaml epochs=50 imgsz=640 batch=32 augment=True project='predict' name='results'
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 139MB/s]
# Ultralytics YOLOv8.2.35 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect predict model=/content/predict/results/weights/best.pt source='/content/Detection-Fresh-Fish-4/test/images/IMG_20230306_100623_jpg.rf.221df66fafe5309280b782b216687ab3.jpg' save=True
# Out:
# Ultralytics YOLOv8.2.35 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/Detection-Fresh-Fish-4/test/images/IMG_20230306_100623_jpg.rf.221df66fafe5309280b782b216687ab3.jpg: 640x640 1 1, 10.0ms
# Speed: 3.1ms preprocess, 10.0ms inference, 1109.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict model=/content/predict/results/weights/best.pt source='/content/60a9d19a67874.jpg' save=True
# Out:
# Ultralytics YOLOv8.2.35 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/60a9d19a67874.jpg: 448x640 2 0s, 89.3ms
# Speed: 3.5ms preprocess, 89.3ms inference, 640.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict model=/content/predict/results/weights/best.pt source='/content/images.jpeg' save=True
# Out:
# Ultralytics YOLOv8.2.35 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/images.jpeg: 384x640 1 1, 98.3ms
# Speed: 3.1ms preprocess, 98.3ms inference, 636.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict model=/content/predict/results/weights/best.pt source='/content/Test2.jpg' save=True
# Out:
# Ultralytics YOLOv8.2.35 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/Test2.jpg: 352x640 2 0s, 2 1s, 91.2ms
# Speed: 2.7ms preprocess, 91.2ms inference, 607.3ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
